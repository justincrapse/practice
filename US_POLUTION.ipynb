# %%
import pandas as pd
import numpy as np

# load in csv_file and set the datetime index
df = pd.read_csv(r'diepandadie/my_data/us_pollution.csv', index_col='Date Local', parse_dates=True)
df.head()
# Out:
#             Unnamed: 0  State Code  County Code  Site Num      Address  \
# Date Local
# 2000-01-01           0           4           13      3002  1645 E R...
# 2000-01-01           1           4           13      3002  1645 E R...
# 2000-01-01           2           4           13      3002  1645 E R...
# 2000-01-01           3           4           13      3002  1645 E R...
# 2000-01-02           4           4           13      3002  1645 E R...
#
#               State    County     City    NO2 Units   NO2 Mean   ...    \
# Date Local                                                       ...
# 2000-01-01  Arizona  Maricopa  Phoenix  Parts pe...  19.041667   ...
# 2000-01-01  Arizona  Maricopa  Phoenix  Parts pe...  19.041667   ...
# 2000-01-01  Arizona  Maricopa  Phoenix  Parts pe...  19.041667   ...
# 2000-01-01  Arizona  Maricopa  Phoenix  Parts pe...  19.041667   ...
# 2000-01-02  Arizona  Maricopa  Phoenix  Parts pe...  22.958333   ...
#
# ...

# %%
# slice datetime index
print(df.loc['February 5, 2010'].shape[0])
print(df.loc['2011-5'].shape[0])
print(df.loc['2004-May-26'].shape[0])
print(df.loc['2000-5-26':'2000-5-28'].shape[0])
# Out:
# 252
# 11790
# 266
# 908

# %%
df['State'].value_counts().head()
# Out:
# California      576142
# Pennsylvania    188892
# Texas           123208
# New York         70487
# Arizona          69840
# Name: State, dtype: int64
